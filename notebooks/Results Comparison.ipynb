# %%
import sys
sys.path.append('../src')
sys.path.append('../data')
from GraphSage import GraphSage
from coraloader import cora_loader
from n_GCN import n_hidden_GCN
from LPA_GCN import LPA_GCN
cora = cora_loader('cora.content',  'cora.cites')
X, y, A = cora.get_train()

# %%
model = GraphSage(A, X, y, agg_func='MAX', len_walk=3, num_neigh=10)
model = GraphSage(A, X, y, agg_func='MEAN', len_walk=3, num_neigh=10)
acc = model.train_epoch(epochs=50, lr=1e-3)

model.draw_cora()
#acc['acc']
# Out:
# Train length :1896, Validation length :812
# Epoch: 0
# training loss 3.3223
# Validtion: Average loss: 2.9512, Accuracy: 26.6010%

# %%
model = LPA_GCN(A, X, y, lamb=10, hid=200)
acc = model.train_model(epochs=50, lr=1e-3)
model.draw_cora()
acc['acc']
# Out:
# Train length :1896, Validation length :812
# Epoch: 0
# training loss 15.7984
# Validtion: Average loss: 1.8809, Accuracy: 21.1823%
# Epoch: 1
# training loss 15.6835
# Validtion: Average loss: 1.7801, Accuracy: 38.4236%
# Epoch: 2
# training loss 15.5766
# Validtion: Average loss: 1.6860, Accuracy: 48.0296%
# Epoch: 3
# training loss 15.4764
# Validtion: Average loss: 1.5979, Accuracy: 50.0000%
# Epoch: 4
# training loss 15.3818
# Validtion: Average loss: 1.5149, Accuracy: 51.6010%
# Epoch: 5
# training loss 15.2921
# Validtion: Average loss: 1.4361, Accuracy: 53.4483%
# Epoch: 6
# training loss 15.2064
# Validtion: Average loss: 1.3600, Accuracy: 55.1724%
# Epoch: 7
# training loss 15.1235
# Validtion: Average loss: 1.2858, Accuracy: 58.9901%
# Epoch: 8
# training loss 15.0426
# Validtion: Average loss: 1.2130, Accuracy: 61.8227%
# Epoch: 9
# training loss 14.9633
# Validtion: Average loss: 1.1413, Accuracy: 64.9015%
# Epoch: 10
# training loss 14.8853
# Validtion: Average loss: 1.0714, Accuracy: 68.5961%
# Epoch: 11
# training loss 14.8094
# Validtion: Average loss: 1.0043, Accuracy: 71.1823%
# Epoch: 12
# training loss 14.7366
# Validtion: Average loss: 0.9406, Accuracy: 75.2463%
# Epoch: 13
# training loss 14.6675
# Validtion: Average loss: 0.8813, Accuracy: 78.6946%
# Epoch: 14
# training loss 14.6032
# Validtion: Average loss: 0.8270, Accuracy: 81.6502%
# Epoch: 15
# training loss 14.5438
# Validtion: Average loss: 0.7777, Accuracy: 83.4975%
# Epoch: 16
# training loss 14.4895
# Validtion: Average loss: 0.7331, Accuracy: 84.4828%
# Epoch: 17
# training loss 14.4401
# Validtion: Average loss: 0.6930, Accuracy: 85.0985%
# Epoch: 18
# training loss 14.3952
# Validtion: Average loss: 0.6569, Accuracy: 85.3448%
# Epoch: 19
# training loss 14.3543
# Validtion: Average loss: 0.6248, Accuracy: 85.9606%
# Epoch: 20
# training loss 14.3172
# Validtion: Average loss: 0.5961, Accuracy: 86.0837%
# Epoch: 21
# training loss 14.2835
# Validtion: Average loss: 0.5710, Accuracy: 86.4532%
# Epoch: 22
# training loss 14.2532
# Validtion: Average loss: 0.5490, Accuracy: 86.5764%
# Epoch: 23
# training loss 14.2260
# Validtion: Average loss: 0.5300, Accuracy: 87.0690%
# Epoch: 24
# training loss 14.2016
# Validtion: Average loss: 0.5134, Accuracy: 86.9458%
# Epoch: 25
# training loss 14.1795
# Validtion: Average loss: 0.4990, Accuracy: 86.9458%
# Epoch: 26
# training loss 14.1595
# Validtion: Average loss: 0.4864, Accuracy: 86.8227%
# Epoch: 27
# training loss 14.1413
# Validtion: Average loss: 0.4752, Accuracy: 86.9458%
# Epoch: 28
# training loss 14.1244
# Validtion: Average loss: 0.4653, Accuracy: 86.8227%
# Epoch: 29
# training loss 14.1089
# Validtion: Average loss: 0.4565, Accuracy: 86.8227%
# Epoch: 30
# training loss 14.0943
# Validtion: Average loss: 0.4487, Accuracy: 87.0690%
# Epoch: 31
# training loss 14.0808
# Validtion: Average loss: 0.4418, Accuracy: 87.1921%
# Epoch: 32
# training loss 14.0681
# Validtion: Average loss: 0.4357, Accuracy: 87.1921%
# Epoch: 33
# training loss 14.0561
# Validtion: Average loss: 0.4302, Accuracy: 87.3153%
# Epoch: 34
# training loss 14.0449
# Validtion: Average loss: 0.4254, Accuracy: 87.3153%
# Epoch: 35
# training loss 14.0343
# Validtion: Average loss: 0.4212, Accuracy: 87.3153%
# Epoch: 36
# training loss 14.0242
# Validtion: Average loss: 0.4174, Accuracy: 86.9458%
# Epoch: 37
# training loss 14.0146
# Validtion: Average loss: 0.4141, Accuracy: 87.0690%
# Epoch: 38
# training loss 14.0055
# Validtion: Average loss: 0.4111, Accuracy: 87.1921%
# Epoch: 39
# training loss 13.9967
# Validtion: Average loss: 0.4085, Accuracy: 87.0690%
# Epoch: 40
# training loss 13.9883
# Validtion: Average loss: 0.4062, Accuracy: 87.0690%
# Epoch: 41
# training loss 13.9803
# Validtion: Average loss: 0.4041, Accuracy: 87.3153%
# Epoch: 42
# training loss 13.9725
# Validtion: Average loss: 0.4023, Accuracy: 87.1921%
# Epoch: 43
# training loss 13.9650
# Validtion: Average loss: 0.4008, Accuracy: 87.3153%
# Epoch: 44
# training loss 13.9577
# Validtion: Average loss: 0.3995, Accuracy: 87.3153%
# Epoch: 45
# training loss 13.9507
# Validtion: Average loss: 0.3984, Accuracy: 87.1921%
# Epoch: 46
# training loss 13.9440
# Validtion: Average loss: 0.3975, Accuracy: 87.3153%
# Epoch: 47
# training loss 13.9374
# Validtion: Average loss: 0.3968, Accuracy: 87.3153%
# Epoch: 48
# training loss 13.9311
# Validtion: Average loss: 0.3963, Accuracy: 87.4384%
# Epoch: 49
# training loss 13.9249
# Validtion: Average loss: 0.3959, Accuracy: 87.5616%

# %%
model = n_hidden_GCN(A, X, y, hidden_neurons=200)
model.train_epoch(epochs=1, lr=1e-3)
model.draw_cora()
# Out:
# Train length :1896, Validation length :812
# Epoch: 0
# training loss 1.9422
# Validtion: Average loss: 0.0000, Accuracy: 27.7094%
